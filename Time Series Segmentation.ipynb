# %% [markdown]
# # General

# %% [markdown]
# ⌛ Mỗi chuỗi thời gian T, gồm các data points có thể được biểu diễn dưới dạng 1 cặp:
#
#
# <font size=4> $T = \{(y_1,t_1),(y_2,t_2),...,(y_n,t_n)\}$

# %% [markdown]
# trong đó:
# * $y_i$ là giá trị của biến quan sát
# * $t_i$ là thời gian

# %% [markdown]
# 📉**Segmentating** là việc chia chuỗi thời gian thành nhiều phần, do đó Segment chính là 1 `TimeSeries`

# %% [markdown]
# Phân đoạn $S$, biểu diễn chuỗi thời gian T, có độ dài là n, dưới dạng tập hợp k phân đoạn liên tiếp, không chồng lên nhau: $S_j (j=1,2,...,k)$

# %% [markdown]
# hay $S=(S_1,S_2,...,S_k)$

# %% [markdown]
# <font size=4>$S_j = \{ s_{ij} \} $ trong đó $s_{ij} = (y_i,t_i)$ với i là thứ tự điểm trong timeseries

# %% [markdown]
# <span style="color: green; font-size: 24px;">&#10004;</span> Giúp làm giảm số chiều  của các giá trị ban đầu!

# %% [markdown]
# ---

# %% [markdown]
# # Process

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ⚠️**selection of the optimal segmentation** dựa trên kích cỡ lỗi(so sánh **các Time Series Segments** với nhau):
#
# <font size=5> $S_{opt}(T,k) = arg \ \ min_{S \in{S_{n,k}}} E_p(T,S)$

# %% [markdown]
# Trong đó:
# * $S_{opt}$ là Segment tối ưu
# * $T$ là TimeSeries ban đầu
# * $k$ là số Segment
# * $n$ là số data points trong T
# * $E_p$ là `khoảng cách Euclide`

# %% [markdown]
# &#128161; Các cách để đánh giá lỗi của **từng Segment trong 1 TimeSeries Segments**

# %% [markdown]
# 👉  `Max error` đánh giá lỗi của từng segment và so sánh với threshold
#
# 👉 `Total max error` tính tổng lỗi của tất cả segment trong 1 Timeseries Segment và so sánh với threshold

# %% [markdown]
# ---

# %% [markdown]
# #  Algorithms

# %% [markdown]
# ## On/Offline algorithms

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Notation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ⚠️ At least two ways to find the approximating line:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 👉 `Linear Interpolation`: Xấp xỉ chuỗi $T[a:b]$ đơn giản là nối các điểm $t_a,t_b$
#
# 👉 `Linear Regression`: Xấp xỉ chuỗi bằng các đoạn độ dài khác nhau để đạt **best fitting line in least squares**

# %% [markdown]
# ## Sliding Window

# %% [markdown]
# 👉 Pseudo-Code

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 👉 Illustration

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Top-down

# %% [markdown]
# 👉 Pseudo-Code

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 👉 Illustration

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Bottom-Up

# %% [markdown]
# 👉 Pseudo-Code

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 👉 Illustration

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Comparison

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# KEY:
# * E : Maximum error for a given segment
# * ME : Maximum error for a given segment for entire time series
# * K : Number of segments
# * L = n/k

# %% [markdown]
# &#128161; Experimental Results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # SWAB

# %% [markdown]
# (Sliding window and Bottom-up)

# %% [markdown]
# 👉 Pseudo-Code

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 👉 Illustration

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Emoji

# %% [markdown]
# <span style="color:red">&#10060;</span> : X
#
# 👉 👇
#
#
# ⚠️
#
# <span style="color: green; font-size: 24px;">&#10004;</span>
# : Dấu tích
#
# &#128161; : bóng đèn
#
# <font size =5> &#x1F9EE; Công thức
#
# <font size =5> &#x1F4DA; : Bài tập
#
# <img src='link' style="width:500px;"/> : Chèn ảnh
#
# <div style="margin-left: 200px;">: căn lề
#
# <span style="color: red;"> Chữ_màu</span>
